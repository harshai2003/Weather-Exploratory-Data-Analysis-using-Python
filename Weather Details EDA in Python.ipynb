# %%
import numpy as np
import pandas as pd

# %%
df_weather = pd.read_csv("Downloads/weather_2012.csv")

# %%
df_weather
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0     2012-01-01 00:00:00      -1.8                -3.9           86
# 1     2012-01-01 01:00:00      -1.8                -3.7           87
# 2     2012-01-01 02:00:00      -1.8                -3.4           89
# 3     2012-01-01 03:00:00      -1.5                -3.2           88
# 4     2012-01-01 04:00:00      -1.5                -3.3           88
# ...                   ...       ...                 ...          ...
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# ...

# %%
df_weather.head(5)
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
df_weather["Weather"].head()
# Out:
# 0                     Fog
# 1                     Fog
# 2    Freezing Drizzle,Fog
# 3    Freezing Drizzle,Fog
# 4                     Fog
# Name: Weather, dtype: object

# %%
df_weather['Date/Time'] = pd.to_datetime(df_weather['Date/Time'])

# %%
df_weather["Date/Time"].head()
# Out:
# 0   2012-01-01 00:00:00
# 1   2012-01-01 01:00:00
# 2   2012-01-01 02:00:00
# 3   2012-01-01 03:00:00
# 4   2012-01-01 04:00:00
# Name: Date/Time, dtype: datetime64[ns]

# %%
df_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date/Time           8784 non-null   datetime64[ns]
#  1   Temp (C)            8784 non-null   float64
#  2   Dew Point Temp (C)  8784 non-null   float64
#  3   Rel Hum (%)         8784 non-null   int64
#  4   Wind Spd (km/h)     8784 non-null   int64
#  5   Visibility (km)     8784 non-null   float64
#  6   Stn Press (kPa)     8784 non-null   float64
#  7   Weather             8784 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(1)
# memory usage: 549.1+ KB

# %%
df_weather["Temp (C)"].head()
# Out:
# 0   -1.8
# 1   -1.8
# 2   -1.8
# 3   -1.5
# 4   -1.5
# Name: Temp (C), dtype: float64

# %%
df_weather["Temp (C)"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8784 entries, 0 to 8783
# Series name: Temp (C)
# Non-Null Count  Dtype
# --------------  -----
# 8784 non-null   float64
# dtypes: float64(1)
# memory usage: 68.8 KB

# %%
df_weather.describe()
# Out:
#                  Date/Time     Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# count                 8784  8784.000000         8784.000000  8784.000000
# mean   2012-07-01 23:30:00     8.798144            2.555294    67.431694
# min    2012-01-01 00:00:00   -23.300000          -28.500000    18.000000
# 25%    2012-04-01 11:45:00     0.100000           -5.900000    56.000000
# 50%    2012-07-01 23:30:00     9.300000            3.300000    68.000000
# 75%    2012-10-01 11:15:00    18.800000           11.800000    81.000000
# max    2012-12-31 23:00:00    33.000000           24.400000   100.000000
# std                    NaN    11.687883           10.883072    16.918881
#
#        Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)
# count      8784.000000      8784.000000      8784.000000
# mean         14.945469        27.664447       101.051623
# min           0.000000         0.200000        97.520000
# 25%           9.000000        24.100000       100.560000
# ...

# %%
df_weather.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
df_weather["Weather"].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
df_weather["Weather"].nunique()
# Out:
# 50

# %%
df_weather[["Weather","Temp (C)"]].head()
# Out:
#                 Weather  Temp (C)
# 0                   Fog      -1.8
# 1                   Fog      -1.8
# 2  Freezing Drizzle,Fog      -1.8
# 3  Freezing Drizzle,Fog      -1.5
# 4                   Fog      -1.5

# %%
df_weather[:30]
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
# 5  2012-01-01 05:00:00      -1.4                -3.3           87
# 6  2012-01-01 06:00:00      -1.5                -3.1           89
# 7  2012-01-01 07:00:00      -1.4                -3.6           85
# 8  2012-01-01 08:00:00      -1.4                -3.6           85
# 9  2012-01-01 09:00:00      -1.3                -3.1           88
# 10 2012-01-01 10:00:00      -1.0                -2.3           91
# 11 2012-01-01 11:00:00      -0.5                -2.1           89
# 12 2012-01-01 12:00:00      -0.2                -2.0           88
# ...

# %%
df_weather[["Weather","Temp (C)"]][0:10:2]
# Out:
#                 Weather  Temp (C)
# 0                   Fog      -1.8
# 2  Freezing Drizzle,Fog      -1.8
# 4                   Fog      -1.5
# 6                   Fog      -1.5
# 8                   Fog      -1.4

# %%
df_weather[["Wind Spd (km/h)", "Visibility (km)"]].loc[0:5]
# Out:
#    Wind Spd (km/h)  Visibility (km)
# 0                4              8.0
# 1                4              8.0
# 2                7              4.0
# 3                6              4.0
# 4                7              4.8
# 5                9              6.4

# %%
df_weather[["Rel Hum (%)", "Visibility (km)"]].iloc[0:5]
# Out:
#    Rel Hum (%)  Visibility (km)
# 0           86              8.0
# 1           87              8.0
# 2           89              4.0
# 3           88              4.0
# 4           88              4.8

# %%
df_weather["Weather"].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
snowed_filter = df_weather['Weather'].str.lower().str.contains('snow')

# %%
snowed_filter.head(50)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41     True
# 42    False
# 43    False
# 44     True
# 45     True
# 46    False
# 47     True
# 48     True
# 49    False
# Name: Weather, dtype: bool

# %%
df_weather[snowed_filter]
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 41    2012-01-02 17:00:00      -2.1                -9.5           57
# 44    2012-01-02 20:00:00      -5.6               -13.4           54
# 45    2012-01-02 21:00:00      -5.8               -12.8           58
# 47    2012-01-02 23:00:00      -7.4               -14.1           59
# 48    2012-01-03 00:00:00      -9.0               -16.0           57
# ...                   ...       ...                 ...          ...
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)       Weather
# ...

# %%
df = df_weather[(df_weather['Wind Spd (km/h)'] > 24) & (df_weather['Visibility (km)']== 25)]
df
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 23    2012-01-01 23:00:00       5.3                 2.0           79
# 24    2012-01-02 00:00:00       5.2                 1.5           77
# 25    2012-01-02 01:00:00       4.6                 0.0           72
# 26    2012-01-02 02:00:00       3.9                -0.9           71
# 27    2012-01-02 03:00:00       3.7                -1.5           69
# ...                   ...       ...                 ...          ...
# 8705  2012-12-28 17:00:00      -8.6               -12.0           76
# 8753  2012-12-30 17:00:00     -12.1               -15.8           74
# 8755  2012-12-30 19:00:00     -13.4               -16.5           77
# 8759  2012-12-30 23:00:00     -12.1               -15.1           78
# 8760  2012-12-31 00:00:00     -11.1               -14.4           77
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)        Weather
# ...

# %%
df.head()
# Out:
#               Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 23  2012-01-01 23:00:00       5.3                 2.0           79
# 24  2012-01-02 00:00:00       5.2                 1.5           77
# 25  2012-01-02 01:00:00       4.6                 0.0           72
# 26  2012-01-02 02:00:00       3.9                -0.9           71
# 27  2012-01-02 03:00:00       3.7                -1.5           69
#
#     Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)        Weather
# 23               30             25.0            99.31         Cloudy
# 24               35             25.0            99.26   Rain Showers
# 25               39             25.0            99.26         Cloudy
# 26               32             25.0            99.26  Mostly Cloudy
# 27               33             25.0            99.30  Mostly Cloudy

# %%
df_weather
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Humidity  \
# 0     2012-01-01 00:00:00      -1.8                -3.9        86
# 1     2012-01-01 01:00:00      -1.8                -3.7        87
# 2     2012-01-01 02:00:00      -1.8                -3.4        89
# 3     2012-01-01 03:00:00      -1.5                -3.2        88
# 4     2012-01-01 04:00:00      -1.5                -3.3        88
# ...                   ...       ...                 ...       ...
# 8779  2012-12-31 19:00:00       0.1                -2.7        81
# 8780  2012-12-31 20:00:00       0.2                -2.4        83
# 8781  2012-12-31 21:00:00      -0.5                -1.5        93
# 8782  2012-12-31 22:00:00      -0.2                -1.8        89
# 8783  2012-12-31 23:00:00       0.0                -2.1        86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                   4              8.0           101.24                   Fog
# ...

# %%
df_weather['new_temp'] = df_weather["Temp (C)"] +  df_weather["Dew Point Temp (C)"]

# %%
df_weather.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather  \
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog
#
#    new_temp
# 0      -5.7
# 1      -5.5
# 2      -5.2
# 3      -4.7
# 4      -4.8

# %%
temp= df_weather['new_temp'] = df_weather["Temp (C)"] +  df_weather["Dew Point Temp (C)"]
temp.head()
# Out:
# 0   -5.7
# 1   -5.5
# 2   -5.2
# 3   -4.7
# 4   -4.8
# dtype: float64

# %%
df_weather["Wind Spd (km/h)"].max()
# Out:
# np.int64(83)

# %%
df_weather["Wind Spd (km/h)"].min()
# Out:
# np.int64(0)

# %%
df_weather["Wind Spd (km/h)"].describe()
# Out:
# count    8784.000000
# mean       14.945469
# std         8.688696
# min         0.000000
# 25%         9.000000
# 50%        13.000000
# 75%        20.000000
# max        83.000000
# Name: Wind Spd (km/h), dtype: float64

# %%
df_weather["Wind Spd (km/h)"].head() * 4/2
# Out:
# 0     8.0
# 1     8.0
# 2    14.0
# 3    12.0
# 4    14.0
# Name: Wind Spd (km/h), dtype: float64

# %%
def func(n):
    x = n*2
    return x

# %%
df_weather['Visibility (km)'].head()
# Out:
# 0    8.0
# 1    8.0
# 2    4.0
# 3    4.0
# 4    4.8
# Name: Visibility (km), dtype: float64

# %%
df_weather['Visibility (km)'].apply(func).head()
# Out:
# 0    16.0
# 1    16.0
# 2     8.0
# 3     8.0
# 4     9.6
# Name: Visibility (km), dtype: float64

# %%
df_weather.rename(columns = {"Rel Hum (%)" : "Humidity"}, inplace = True)
df_weather.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Humidity  \
# 0  2012-01-01 00:00:00      -1.8                -3.9        86
# 1  2012-01-01 01:00:00      -1.8                -3.7        87
# 2  2012-01-01 02:00:00      -1.8                -3.4        89
# 3  2012-01-01 03:00:00      -1.5                -3.2        88
# 4  2012-01-01 04:00:00      -1.5                -3.3        88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
df_weather.drop(labels=["Stn Press (kPa)"], axis=1)
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Humidity  \
# 0     2012-01-01 00:00:00      -1.8                -3.9        86
# 1     2012-01-01 01:00:00      -1.8                -3.7        87
# 2     2012-01-01 02:00:00      -1.8                -3.4        89
# 3     2012-01-01 03:00:00      -1.5                -3.2        88
# 4     2012-01-01 04:00:00      -1.5                -3.3        88
# ...                   ...       ...                 ...       ...
# 8779  2012-12-31 19:00:00       0.1                -2.7        81
# 8780  2012-12-31 20:00:00       0.2                -2.4        83
# 8781  2012-12-31 21:00:00      -0.5                -1.5        93
# 8782  2012-12-31 22:00:00      -0.2                -1.8        89
# 8783  2012-12-31 23:00:00       0.0                -2.1        86
#
#       Wind Spd (km/h)  Visibility (km)               Weather
# 0                   4              8.0                   Fog
# ...

# %%
df_weather.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Humidity  \
# 0  2012-01-01 00:00:00      -1.8                -3.9        86
# 1  2012-01-01 01:00:00      -1.8                -3.7        87
# 2  2012-01-01 02:00:00      -1.8                -3.4        89
# 3  2012-01-01 03:00:00      -1.5                -3.2        88
# 4  2012-01-01 04:00:00      -1.5                -3.3        88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
df_weather.sort_values('Temp (C)', ascending=True)
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Humidity  \
# 344   2012-01-15 08:00:00     -23.3               -28.5        62
# 342   2012-01-15 06:00:00     -23.2               -28.5        62
# 343   2012-01-15 07:00:00     -22.8               -28.0        62
# 345   2012-01-15 09:00:00     -22.2               -27.8        60
# 338   2012-01-15 02:00:00     -21.4               -26.6        63
# ...                   ...       ...                 ...       ...
# 4694  2012-07-14 14:00:00      32.7                15.3        35
# 5199  2012-08-04 15:00:00      32.8                18.8        44
# 4696  2012-07-14 16:00:00      32.9                15.3        35
# 4695  2012-07-14 15:00:00      33.0                16.8        38
# 4143  2012-06-21 15:00:00      33.0                19.0        44
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)        Weather
# 344                 7             24.1           102.45          Clear
# ...

# %%
df_weather.sort_values('Temp (C)', ascending=True)
df_weather.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Humidity  \
# 0  2012-01-01 00:00:00      -1.8                -3.9        86
# 1  2012-01-01 01:00:00      -1.8                -3.7        87
# 2  2012-01-01 02:00:00      -1.8                -3.4        89
# 3  2012-01-01 03:00:00      -1.5                -3.2        88
# 4  2012-01-01 04:00:00      -1.5                -3.3        88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
data = {
    'A': ['X','Y','Z','K','R','L'],
    'B': ['one','two','three','four','five','six'],
    'C': ['a','b','c','d','e','f'],
    'D': [1, 3, 2, 6, 9, 5]
}

df = pd.DataFrame(data)
df
# Out:
#    A      B  C  D
# 0  X    one  a  1
# 1  Y    two  b  3
# 2  Z  three  c  2
# 3  K   four  d  6
# 4  R   five  e  9
# 5  L    six  f  5

# %%
df_pivot = df.pivot_table(
    index = 'B',
    values = 'D',
    columns = ['A'])

df_pivot
# Out:
# A        K    L    R    X    Y    Z
# B
# five   NaN  NaN  9.0  NaN  NaN  NaN
# four   6.0  NaN  NaN  NaN  NaN  NaN
# one    NaN  NaN  NaN  1.0  NaN  NaN
# six    NaN  5.0  NaN  NaN  NaN  NaN
# three  NaN  NaN  NaN  NaN  NaN  2.0
# two    NaN  NaN  NaN  NaN  3.0  NaN

# %%
df1 = pd.DataFrame({
    'A': ['A0', 'A1', 'A2', 'A3'],
    'B': ['B0', 'B1', 'B2', 'B3'],
    'C': ['C0', 'C1', 'C2', 'C3'],
    'D': ['D0', 'D1', 'D2', 'D3']
}, index=[0, 1, 2, 3])

df2 = pd.DataFrame({
    'A': ['A4', 'A5', 'A6', 'A7'],
    'B': ['B4', 'B5', 'B6', 'B7'],
    'C': ['C4', 'C5', 'C6', 'C7'],
    'D': ['D4', 'D5', 'D6', 'D7']
}, index=[4, 5, 6, 7])

df3 = pd.DataFrame({
    'A': ['A8', 'A9', 'A10', 'A11'],
    'B': ['B8', 'B9', 'B10', 'B11'],
    'C': ['C8', 'C9', 'C10', 'C11'],
    'E': ['D8', 'D9', 'D10', 'D11']
}, index=[8, 9, 10, 11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    E
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D    E
# 0    A0   B0   C0   D0  NaN
# 1    A1   B1   C1   D1  NaN
# 2    A2   B2   C2   D2  NaN
# 3    A3   B3   C3   D3  NaN
# 4    A4   B4   C4   D4  NaN
# 5    A5   B5   C5   D5  NaN
# 6    A6   B6   C6   D6  NaN
# 7    A7   B7   C7   D7  NaN
# 8    A8   B8   C8  NaN   D8
# 9    A9   B9   C9  NaN   D9
# 10  A10  B10  C10  NaN  D10
# 11  A11  B11  C11  NaN  D11

# %%
pd.concat([df1,df2,df3], axis=1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    E
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
left_df = pd.DataFrame({
    'A': ['A0', 'A1', 'A2'],
    'B': ['B0', 'B1', 'B2']
}, index=['K0', 'K1', 'K2']) 

right_df = pd.DataFrame({
    'C': ['C0', 'C2', 'C3'],
    'D': ['D0', 'D2', 'D3']
}, index=['K0', 'K2', 'K3'])

# %%
left_df
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
right_df
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
left_df.join(right_df, how = 'inner')
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K2  A2  B2  C2  D2

# %%
left_df.join(right_df, how = 'outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %%
left = pd.DataFrame({
    'key1': ['K0', 'K0', 'K1', 'K2'],
    'key2': ['K0', 'K1', 'K0', 'K1'],
    'A': ['A0', 'A1', 'A2', 'A3'],
    'B': ['B0', 'B1', 'B2', 'B3']
})
    
right = pd.DataFrame({
    'key1': ['K0', 'K1', 'K1', 'K2'],
    'key2': ['K0', 'K0', 'K0', 'K0'],
    'C': ['C0', 'C1', 'C2', 'C3'],
    'D': ['D0', 'D1', 'D2', 'D3']
})

# %%
left
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
right
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
pd.merge(left, right, how= 'left', on= ['key1', 'key2'])
# Out:
#   key1 key2   A   B    C    D
# 0   K0   K0  A0  B0   C0   D0
# 1   K0   K1  A1  B1  NaN  NaN
# 2   K1   K0  A2  B2   C1   D1
# 3   K1   K0  A2  B2   C2   D2
# 4   K2   K1  A3  B3  NaN  NaN
